# %%
import pandas as pd
import glob
import os

# %%
csv_files = glob.glob('G:/My Drive/TCR/EANM/*.csv')
file_dict = {}

for file_path in csv_files:
    file_name = os.path.basename(file_path)
    key = os.path.splitext(file_name)[0]  # remove the file extension
    file_dict[key] = file_path

# %%
key_name = 'moving.nii_0000_HCPA_EANM_CLINICO8MIN'
df = pd.read_csv(file_dict[key_name], sep=';', skiprows=range(1, 11))
df.rename(columns={'0': 'Value'}, inplace=True)
df
# Out:
#                                      Data ID     Value
# 0                           Left_Hippocampus  0.813185
# 1                          Right_Hippocampus  0.857568
# 2                              Left_Amygdala  0.944792
# 3                             Right_Amygdala  0.921172
# 4    Left_Anterior_temporal_lobe_medial_part  0.712149
# ..                                       ...       ...
# 130             Left_Superior_parietal_gyrus  0.426224
# 131                      Right_Lingual_gyrus  0.407855
# 132                       Left_Lingual_gyrus  0.466789
# 133                             Right_Cuneus  0.490319
# 134                              Left_Cuneus  0.482223
#
# [135 rows x 2 columns]

# %%
# Separate the left and right regions into separate columns
df['Side'] = df['Data ID'].str.split('_').str[0]
df['Region'] = df['Data ID'].str.split('_').str[1:].str.join('_')
df.drop('Data ID', axis=1, inplace=True)
df = df[~(df['Side'] == 'Brainstem')]
df = df[~(df['Side'] == 'Corpus')]
df = df[~(df['Side'] == 'Regional WM recovery coefficients using full mask')]
df = df[~(df['Side'] == 'Third')]
df_1 = df[0:64]
df_2 = df[64:]

# %%
grouped = df_1.groupby(['Region', 'Side']).sum().reset_index()

# %%
pivoted_1 = grouped.pivot(index='Region', columns='Side', values='Value')
pivoted_1
# Out:
# Side                                           Left     Right
# Region
# Amygdala                                   0.944792  0.921172
# Anterior_temporal_lobe_lateral_part        0.812641  0.851109
# Anterior_temporal_lobe_medial_part         0.712149  0.790743
# Caudate_nucleus                            0.780970  0.777261
# Cerebellum                                 0.833456  0.890420
# Cuneus                                     0.785922  0.790542
# Fusiform_gyrus                             0.722744  0.778420
# Gyrus_cinguli_anterior_part                0.986031  0.996815
# Gyrus_cinguli_posterior_part               0.992522  0.908732
# Gyrus_rectus                               0.848167  0.768392
# Hippocampus                                0.813185  0.857568
# Inferior_frontal_gyrus                     0.874864  0.891726
# Inferolateral_remainder_of_parietal_lobe   0.760904  0.739511
# Insula                                     0.942617  0.962782
# Lateral_remainder_of_occipital_lobe        0.798353  0.820904
# Lateral_ventricle_excluding_temporal_horn  0.536112  0.513414
# Lateral_ventricle_temporal_horn            0.830323  0.547707
# Lingual_gyrus                              0.887098  0.850028
# Middle_and_inferior_temporal_gyri          0.785425  0.836266
# Middle_frontal_gyrus                       0.833445  0.828998
# Nucleus_accumbens                          0.890650  0.861208
# Orbitofrontal_gyri                         0.782678  0.806215
# Pallidum                                   0.946172  0.940204
# Parahippocampal_and_ambient_gyri           0.732166  0.756249
# Postcentral_gyrus                          0.736721  0.736798
# Posterior_temporal_lobe                    0.846094  0.873002
# Precentral_gyrus                           0.789610  0.789465
# Putamen                                    0.907306  0.905663
# Superior_frontal_gyrus                     0.836762  0.867099
# Superior_parietal_gyrus                    0.732086  0.731469
# Superior_temporal_gyrus                    0.831579  0.888220
# Thalamus                                   0.905876  0.916861

# %%
pivoted_1['Ratio'] = pivoted_1['Left'] / pivoted_1['Right']
pivoted_1
# Out:
# Side                                           Left     Right     Ratio
# Region
# Amygdala                                   0.944792  0.921172  1.025641
# Anterior_temporal_lobe_lateral_part        0.812641  0.851109  0.954802
# Anterior_temporal_lobe_medial_part         0.712149  0.790743  0.900607
# Caudate_nucleus                            0.780970  0.777261  1.004772
# Cerebellum                                 0.833456  0.890420  0.936026
# Cuneus                                     0.785922  0.790542  0.994156
# Fusiform_gyrus                             0.722744  0.778420  0.928476
# Gyrus_cinguli_anterior_part                0.986031  0.996815  0.989182
# Gyrus_cinguli_posterior_part               0.992522  0.908732  1.092205
# Gyrus_rectus                               0.848167  0.768392  1.103821
# Hippocampus                                0.813185  0.857568  0.948246
# Inferior_frontal_gyrus                     0.874864  0.891726  0.981091
# Inferolateral_remainder_of_parietal_lobe   0.760904  0.739511  1.028929
# Insula                                     0.942617  0.962782  0.979055
# Lateral_remainder_of_occipital_lobe        0.798353  0.820904  0.972529
# Lateral_ventricle_excluding_temporal_horn  0.536112  0.513414  1.044210
# Lateral_ventricle_temporal_horn            0.830323  0.547707  1.515999
# Lingual_gyrus                              0.887098  0.850028  1.043610
# Middle_and_inferior_temporal_gyri          0.785425  0.836266  0.939205
# Middle_frontal_gyrus                       0.833445  0.828998  1.005364
# Nucleus_accumbens                          0.890650  0.861208  1.034187
# Orbitofrontal_gyri                         0.782678  0.806215  0.970806
# Pallidum                                   0.946172  0.940204  1.006348
# Parahippocampal_and_ambient_gyri           0.732166  0.756249  0.968155
# Postcentral_gyrus                          0.736721  0.736798  0.999895
# Posterior_temporal_lobe                    0.846094  0.873002  0.969178
# Precentral_gyrus                           0.789610  0.789465  1.000184
# Putamen                                    0.907306  0.905663  1.001814
# Superior_frontal_gyrus                     0.836762  0.867099  0.965013
# Superior_parietal_gyrus                    0.732086  0.731469  1.000844
# Superior_temporal_gyrus                    0.831579  0.888220  0.936231
# Thalamus                                   0.905876  0.916861  0.988019

# %%
grouped = df_2.groupby(['Region', 'Side']).sum().reset_index()

# %%
pivoted_2 = grouped.pivot(index='Region', columns='Side', values='Value')
pivoted_2
# Out:
# Side                                           Left     Right
# Region
# Amygdala                                   0.441831  0.456170
# Anterior_temporal_lobe_lateral_part        0.600200  0.544822
# Anterior_temporal_lobe_medial_part         0.515469  0.462855
# Caudate_nucleus                            0.360153  0.376003
# Cerebellum                                 0.478444  0.465232
# Cuneus                                     0.482223  0.490319
# Fusiform_gyrus                             0.401538  0.490224
# Gyrus_cinguli_anterior_part                0.621311  0.596408
# Gyrus_cinguli_posterior_part               0.661134  0.557328
# Gyrus_rectus                               0.405964  0.354983
# Hippocampus                                0.463203  0.497519
# Inferior_frontal_gyrus                     0.498489  0.539937
# Inferolateral_remainder_of_parietal_lobe   0.436562  0.438405
# Insula                                     0.449440  0.455511
# Lateral_remainder_of_occipital_lobe        0.422732  0.461666
# Lateral_ventricle_excluding_temporal_horn  0.181546  0.213891
# Lateral_ventricle_temporal_horn            0.508688  0.402589
# Lingual_gyrus                              0.466789  0.407855
# Middle_and_inferior_temporal_gyri          0.459886  0.494404
# Middle_frontal_gyrus                       0.401426  0.405133
# Nucleus_accumbens                          0.397666  0.512850
# Orbitofrontal_gyri                         0.415096  0.440225
# Pallidum                                   0.434955  0.394620
# Parahippocampal_and_ambient_gyri           0.323928  0.392468
# Postcentral_gyrus                          0.420751  0.419846
# Posterior_temporal_lobe                    0.385514  0.390716
# Precentral_gyrus                           0.467928  0.435936
# Putamen                                    0.586801  0.565972
# Superior_frontal_gyrus                     0.439486  0.435048
# Superior_parietal_gyrus                    0.426224  0.435534
# Superior_temporal_gyrus                    0.485989  0.479100
# Thalamus                                   0.341095  0.353317

# %%
pivoted_2['Ratio'] = pivoted_2['Left'] / pivoted_2['Right']
pivoted_2
# Out:
# Side                                           Left     Right     Ratio
# Region
# Amygdala                                   0.441831  0.456170  0.968567
# Anterior_temporal_lobe_lateral_part        0.600200  0.544822  1.101644
# Anterior_temporal_lobe_medial_part         0.515469  0.462855  1.113673
# Caudate_nucleus                            0.360153  0.376003  0.957846
# Cerebellum                                 0.478444  0.465232  1.028399
# Cuneus                                     0.482223  0.490319  0.983488
# Fusiform_gyrus                             0.401538  0.490224  0.819091
# Gyrus_cinguli_anterior_part                0.621311  0.596408  1.041755
# Gyrus_cinguli_posterior_part               0.661134  0.557328  1.186257
# Gyrus_rectus                               0.405964  0.354983  1.143615
# Hippocampus                                0.463203  0.497519  0.931026
# Inferior_frontal_gyrus                     0.498489  0.539937  0.923235
# Inferolateral_remainder_of_parietal_lobe   0.436562  0.438405  0.995796
# Insula                                     0.449440  0.455511  0.986672
# Lateral_remainder_of_occipital_lobe        0.422732  0.461666  0.915666
# Lateral_ventricle_excluding_temporal_horn  0.181546  0.213891  0.848778
# Lateral_ventricle_temporal_horn            0.508688  0.402589  1.263542
# Lingual_gyrus                              0.466789  0.407855  1.144497
# Middle_and_inferior_temporal_gyri          0.459886  0.494404  0.930183
# Middle_frontal_gyrus                       0.401426  0.405133  0.990850
# Nucleus_accumbens                          0.397666  0.512850  0.775404
# Orbitofrontal_gyri                         0.415096  0.440225  0.942918
# Pallidum                                   0.434955  0.394620  1.102212
# Parahippocampal_and_ambient_gyri           0.323928  0.392468  0.825362
# Postcentral_gyrus                          0.420751  0.419846  1.002156
# Posterior_temporal_lobe                    0.385514  0.390716  0.986686
# Precentral_gyrus                           0.467928  0.435936  1.073387
# Putamen                                    0.586801  0.565972  1.036802
# Superior_frontal_gyrus                     0.439486  0.435048  1.010201
# Superior_parietal_gyrus                    0.426224  0.435534  0.978624
# Superior_temporal_gyrus                    0.485989  0.479100  1.014379
# Thalamus                                   0.341095  0.353317  0.965408

# %%
concatenated_df = pd.concat([pivoted_1, pivoted_2])
concatenated_df
# Out:
# Side                                     Left     Right     Ratio
# Region
# Amygdala                             0.944792  0.921172  1.025641
# Anterior_temporal_lobe_lateral_part  0.812641  0.851109  0.954802
# Anterior_temporal_lobe_medial_part   0.712149  0.790743  0.900607
# Caudate_nucleus                      0.780970  0.777261  1.004772
# Cerebellum                           0.833456  0.890420  0.936026
# ...                                       ...       ...       ...
# Putamen                              0.586801  0.565972  1.036802
# Superior_frontal_gyrus               0.439486  0.435048  1.010201
# Superior_parietal_gyrus              0.426224  0.435534  0.978624
# Superior_temporal_gyrus              0.485989  0.479100  1.014379
# Thalamus                             0.341095  0.353317  0.965408
#
# [64 rows x 3 columns]

# %%
concatenated_df.to_csv('G:/My Drive/Projetos Python/EANM_Analysis/' + key_name + '.csv', index=True)
